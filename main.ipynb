# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from tqdm import tqdm_notebook

# %%
df = pd.read_csv('./data/water_potability.csv')
df.shape
# Out:
# (3276, 10)

# %%
df.describe().T.style.bar(
    subset=['mean'],
    color='#606ff2').background_gradient(
    subset=['std'], cmap='PuBu').background_gradient(subset=['50%'], cmap='PuBu')
# Out:
# <style  type="text/css" >
# #T_df5415ee_44f9_11ec_a86f_00155daa5a7crow0_col1,#T_df5415ee_44f9_11ec_a86f_00155daa5a7crow3_col1,#T_df5415ee_44f9_11ec_a86f_00155daa5a7crow8_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#606ff2 0.0%, transparent 0.0%);
#         }#T_df5415ee_44f9_11ec_a86f_00155daa5a7crow0_col2,#T_df5415ee_44f9_11ec_a86f_00155daa5a7crow0_col5,#T_df5415ee_44f9_11ec_a86f_00155daa5a7crow1_col2,#T_df5415ee_44f9_11ec_a86f_00155daa5a7crow3_col2,#T_df5415ee_44f9_11ec_a86f_00155daa5a7crow3_col5,#T_df5415ee_44f9_11ec_a86f_00155daa5a7crow6_col2,#T_df5415ee_44f9_11ec_a86f_00155daa5a7crow6_col5,#T_df5415ee_44f9_11ec_a86f_00155daa5a7crow7_col2,#T_df5415ee_44f9_11ec_a86f_00155daa5a7crow7_col5,#T_df5415ee_44f9_11ec_a86f_00155daa5a7crow8_col2,#T_df5415ee_44f9_11ec_a86f_00155daa5a7crow8_col5,#T_df5415ee_44f9_11ec_a86f_00155daa5a7crow9_col2,#T_df5415ee_44f9_11ec_a86f_00155daa5a7crow9_col5{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_df5415ee_44f9_11ec_a86f_00155daa5a7crow1_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#606ff2 0.9%, transparent 0.9%);
#         }#T_df5415ee_44f9_11ec_a86f_00155daa5a7crow1_col5,#T_df5415ee_44f9_11ec_a86f_00155daa5a7crow5_col2{
#             background-color:  #fef6fa;
#             color:  #000000;
#         }#T_df5415ee_44f9_11ec_a86f_00155daa5a7crow2_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#606ff2 100.0%, transparent 100.0%);
#         }#T_df5415ee_44f9_11ec_a86f_00155daa5a7crow2_col2,#T_df5415ee_44f9_11ec_a86f_00155daa5a7crow2_col5{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_df5415ee_44f9_11ec_a86f_00155daa5a7crow4_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#606ff2 1.5%, transparent 1.5%);
#         }#T_df5415ee_44f9_11ec_a86f_00155daa5a7crow4_col2{
#             background-color:  #fef6fb;
#             color:  #000000;
#         }#T_df5415ee_44f9_11ec_a86f_00155daa5a7crow4_col5{
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }#T_df5415ee_44f9_11ec_a86f_00155daa5a7crow5_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#606ff2 1.9%, transparent 1.9%);
#         }#T_df5415ee_44f9_11ec_a86f_00155daa5a7crow5_col5{
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }#T_df5415ee_44f9_11ec_a86f_00155daa5a7crow6_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#606ff2 0.1%, transparent 0.1%);
#         }#T_df5415ee_44f9_11ec_a86f_00155daa5a7crow7_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#606ff2 0.3%, transparent 0.3%);
#         }#T_df5415ee_44f9_11ec_a86f_00155daa5a7crow9_col1{
#             width:  10em;
#              height:  80%;
#         }</style><table id="T_df5415ee_44f9_11ec_a86f_00155daa5a7c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >count</th>        <th class="col_heading level0 col1" >mean</th>        <th class="col_heading level0 col2" >std</th>        <th class="col_heading level0 col3" >min</th>        <th class="col_heading level0 col4" >25%</th>        <th class="col_heading level0 col5" >50%</th>        <th class="col_heading level0 col6" >75%</th>        <th class="col_heading level0 col7" >max</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_df5415ee_44f9_11ec_a86f_00155daa5a7clevel0_row0" class="row_heading level0 row0" >ph</th>
#                         <td id="T_df5415ee_44f9_11ec_a86f_00155daa5a7crow0_col0" class="data row0 col0" >2785.000000</td>
#                         <td id="T_df5415ee_44f9_11ec_a86f_00155daa5a7crow0_col1" class="data row0 col1" >7.080795</td>
#                         <td id="T_df5415ee_44f9_11ec_a86f_00155daa5a7crow0_col2" class="data row0 col2" >1.594320</td>
#                         <td id="T_df5415ee_44f9_11ec_a86f_00155daa5a7crow0_col3" class="data row0 col3" >0.000000</td>
#                         <td id="T_df5415ee_44f9_11ec_a86f_00155daa5a7crow0_col4" class="data row0 col4" >6.093092</td>
#                         <td id="T_df5415ee_44f9_11ec_a86f_00155daa5a7crow0_col5" class="data row0 col5" >7.036752</td>
#                         <td id="T_df5415ee_44f9_11ec_a86f_00155daa5a7crow0_col6" class="data row0 col6" >8.062066</td>
#                         <td id="T_df5415ee_44f9_11ec_a86f_00155daa5a7crow0_col7" class="data row0 col7" >14.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_df5415ee_44f9_11ec_a86f_00155daa5a7clevel0_row1" class="row_heading level0 row1" >Hardness</th>
#                         <td id="T_df5415ee_44f9_11ec_a86f_00155daa5a7crow1_col0" class="data row1 col0" >3276.000000</td>
#                         <td id="T_df5415ee_44f9_11ec_a86f_00155daa5a7crow1_col1" class="data row1 col1" >196.369496</td>
#                         <td id="T_df5415ee_44f9_11ec_a86f_00155daa5a7crow1_col2" class="data row1 col2" >32.879761</td>
#                         <td id="T_df5415ee_44f9_11ec_a86f_00155daa5a7crow1_col3" class="data row1 col3" >47.432000</td>
#                         <td id="T_df5415ee_44f9_11ec_a86f_00155daa5a7crow1_col4" class="data row1 col4" >176.850538</td>
#                         <td id="T_df5415ee_44f9_11ec_a86f_00155daa5a7crow1_col5" class="data row1 col5" >196.967627</td>
#                         <td id="T_df5415ee_44f9_11ec_a86f_00155daa5a7crow1_col6" class="data row1 col6" >216.667456</td>
#                         <td id="T_df5415ee_44f9_11ec_a86f_00155daa5a7crow1_col7" class="data row1 col7" >323.124000</td>
#             </tr>
#             <tr>
#                         <th id="T_df5415ee_44f9_11ec_a86f_00155daa5a7clevel0_row2" class="row_heading level0 row2" >Solids</th>
#                         <td id="T_df5415ee_44f9_11ec_a86f_00155daa5a7crow2_col0" class="data row2 col0" >3276.000000</td>
#                         <td id="T_df5415ee_44f9_11ec_a86f_00155daa5a7crow2_col1" class="data row2 col1" >22014.092526</td>
#                         <td id="T_df5415ee_44f9_11ec_a86f_00155daa5a7crow2_col2" class="data row2 col2" >8768.570828</td>
#                         <td id="T_df5415ee_44f9_11ec_a86f_00155daa5a7crow2_col3" class="data row2 col3" >320.942611</td>
#                         <td id="T_df5415ee_44f9_11ec_a86f_00155daa5a7crow2_col4" class="data row2 col4" >15666.690297</td>
#                         <td id="T_df5415ee_44f9_11ec_a86f_00155daa5a7crow2_col5" class="data row2 col5" >20927.833607</td>
#                         <td id="T_df5415ee_44f9_11ec_a86f_00155daa5a7crow2_col6" class="data row2 col6" >27332.762127</td>
#                         <td id="T_df5415ee_44f9_11ec_a86f_00155daa5a7crow2_col7" class="data row2 col7" >61227.196008</td>
#             </tr>
#             <tr>
#                         <th id="T_df5415ee_44f9_11ec_a86f_00155daa5a7clevel0_row3" class="row_heading level0 row3" >Chloramines</th>
#                         <td id="T_df5415ee_44f9_11ec_a86f_00155daa5a7crow3_col0" class="data row3 col0" >3276.000000</td>
#                         <td id="T_df5415ee_44f9_11ec_a86f_00155daa5a7crow3_col1" class="data row3 col1" >7.122277</td>
#                         <td id="T_df5415ee_44f9_11ec_a86f_00155daa5a7crow3_col2" class="data row3 col2" >1.583085</td>
#                         <td id="T_df5415ee_44f9_11ec_a86f_00155daa5a7crow3_col3" class="data row3 col3" >0.352000</td>
#                         <td id="T_df5415ee_44f9_11ec_a86f_00155daa5a7crow3_col4" class="data row3 col4" >6.127421</td>
#                         <td id="T_df5415ee_44f9_11ec_a86f_00155daa5a7crow3_col5" class="data row3 col5" >7.130299</td>
#                         <td id="T_df5415ee_44f9_11ec_a86f_00155daa5a7crow3_col6" class="data row3 col6" >8.114887</td>

# %%
df.isnull().values.any()
# Out:
# True

# %%
percent_missing = df.isnull().sum() * 100 / len(df)
missing_value_df = pd.DataFrame({'column_name': df.columns,
                                 'percent_missing': percent_missing})
missing_value_df
# Out:
#                      column_name  percent_missing
# ph                            ph        14.987790
# Hardness                Hardness         0.000000
# Solids                    Solids         0.000000
# Chloramines          Chloramines         0.000000
# Sulfate                  Sulfate        23.840049
# Conductivity        Conductivity         0.000000
# Organic_carbon    Organic_carbon         0.000000
# Trihalomethanes  Trihalomethanes         4.945055
# Turbidity              Turbidity         0.000000
# Potability            Potability         0.000000

# %%
n_total_rows = df.shape[0]
n_miss_row = df[df.isnull().any(axis=1)].shape[0]
print(f'Missing rows / total rows = {n_miss_row}/{n_total_rows} = {round(n_miss_row/n_total_rows, 3) * 100}%')
# Out:
# Missing rows / total rows = 1265/3276 = 38.6%

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x="Potability", data=df, palette='husl');

# %%
cols = ['ph', 'Hardness', 'Solids', 'Chloramines', 'Sulfate', 'Conductivity',
       'Organic_carbon', 'Trihalomethanes', 'Turbidity']

# %%
def boxPlotter(dataset, columnName):
    """
    Plots boxplots for column given as parameter.
    """
    sns.catplot(x="Potability", y=columnName, data=dataset, kind="box");
for column in tqdm_notebook(cols, desc = "Your Charts are being ready"):
    boxPlotter(df, column)
# Out:
# d:\study\pythonprj\pythonproject\venv\lib\site-packages\ipykernel_launcher.py:6: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(HTML(value='Your Charts are being ready'), FloatProgress(value=0.0, max=9.0), HTML(value='')))

# %%
def pieChartPlotter(dataset, columnName):
    """
    Creates pie chart of the column given as parameter in the dataset
    """
    values = dataset[columnName].value_counts()
    labels = dataset[columnName].unique()
    pie, ax = plt.subplots(figsize=[10, 6])

    patches, texts, autotexts = ax.pie(values, labels=labels, autopct='%1.2f%%', shadow=True, pctdistance=.5,explode=[0.06]*dataset[columnName].unique()
                                       )

    plt.legend(patches, labels, loc="best")
    plt.title(columnName, color='white', fontsize=14)
    plt.setp(texts, color='white', fontsize=20)
    plt.setp(autotexts, size=10, color='black')
    autotexts[1].set_color('black')
    plt.axis('equal')
    plt.tight_layout()
    plt.show()

pieChartPlotter(df, 'Potability')
